# %%
import pandas as pd 
import numpy as np
import math


bridges = pd.read_csv("bridges.csv", index_col = "id")
bridges.head()
# Out:
#                                         name         start_neighborhood  \
# id
# 2002832442                Fort Duquesne Blvd  Central Business District
# 761156487                 28th Street Bridge             Strip District
# 290122944               Second Avenue Bridge        Squirrel Hill South
# 1811170969           Alexander Street Bridge                   West End
# 2047190591  Millvale Trail Pedestrian Bridge                  Troy Hill
#
#            end_neighborhood  year_built  year_rehab  \
# id
# 2002832442              NaN         NaN         NaN
# 761156487       Polish Hill      1931.0      1974.0
# 290122944    Swisshelm Park      1886.0      1970.0
# 1811170969              NaN      1924.0      2000.0
# 2047190591              NaN         NaN         NaN
#
#                                                         image  \
# id
# 2002832442                                                NaN
# 761156487   https://tools.wprdc.org/images/pittsburgh/brid...
# 290122944                                                 NaN
# 1811170969  https://tools.wprdc.org/images/pittsburgh/brid...
# 2047190591                                                NaN
#
#                          neighborhood  council_district  ward        tract  \
# id
# 2002832442  Central Business District                 6   2.0  42003020100
# 761156487              Strip District                 7   6.0  42003060500
# 290122944              Swisshelm Park                 5  14.0  42003141400
# 1811170969                   West End                 2  20.0  42003562600
# 2047190591                  Troy Hill                 1  24.0  42003240600
#
#             public_works_division  pli_division  police_zone fire_zone  \
# id
# 2002832442                    6.0           2.0          2.0       1-3
# 761156487                     6.0           6.0          2.0      2-25
# 290122944                     3.0          14.0          4.0      2-12
# 1811170969                    5.0          20.0          6.0      1-17
# 2047190591                    1.0          24.0          1.0       1-1
#
#              latitude  longitude
# id
# 2002832442  40.446450 -79.996537
# 761156487   40.456182 -79.973714
# 290122944   40.415210 -79.915699
# 1811170969  40.440063 -80.033353
# 2047190591  40.466586 -79.977731

# %%
neighborhood = dict()

for index, row in bridges.iterrows():
    if row["neighborhood"] in neighborhood:
        neighborhood[row["neighborhood"]] = neighborhood[row["neighborhood"]] + 1
    else:
        neighborhood[row["neighborhood"]] = 1
        
print(neighborhood)
# Out:
# {'Central Business District': 12, 'Strip District': 1, 'Swisshelm Park': 2, 'West End': 4, 'Troy Hill': 7, 'Squirrel Hill South': 14, 'Brookline': 1, 'Overbrook': 6, 'Arlington': 2, 'Oakwood': 5, 'Bloomfield': 2, 'Greenfield': 2, 'Polish Hill': 3, 'Lower Lawrenceville': 2, 'Brighton Heights': 2, 'Hays': 6, 'Beechview': 1, 'Banksville': 1, 'Shadyside': 6, 'Central Oakland': 1, 'Sheraden': 3, 'East Allegheny': 4, 'Manchester': 1, 'Mount Washington': 4, 'Larimer': 3, 'East Liberty': 2, 'Summer Hill': 1, 'Bon Air': 3, 'Bluff': 2, 'South Oakland': 4, 'Hazelwood': 4, 'Point Breeze': 1, 'Squirrel Hill North': 2, nan: 4, 'Allentown': 1, 'South Side Flats': 5, 'Spring Hill-City View': 1, 'Allegheny Center': 3, 'Lincoln-Lemington-Belmar': 2, 'Perry South': 2, 'Northview Heights': 1, 'South Side Slopes': 5, 'Allegheny West': 2, 'Homewood South': 1, 'Highland Park': 2, 'California-Kirkbride': 1, 'Marshall-Shadeland': 2, 'South Shore': 1, 'Esplen': 1, 'Elliott': 1, 'Regent Square': 1, 'Windgap': 2, 'North Shore': 1}

# %%
bridgescount = pd.DataFrame(list(neighborhood.items()), columns = ['neighborhood', '# of bridges'])
bridgescount_sorted = bridgescount.sort_values("# of bridges", ascending = False)
bridgescount_sorted.head(len(bridgescount))
# Out:
#                  neighborhood  # of bridges
# 5         Squirrel Hill South            14
# 0   Central Business District            12
# 4                   Troy Hill             7
# 7                   Overbrook             6
# 15                       Hays             6
# 18                  Shadyside             6
# 9                     Oakwood             5
# 35           South Side Flats             5
# 41          South Side Slopes             5
# 33                        NaN             4
# 3                    West End             4
# 30                  Hazelwood             4
# 29              South Oakland             4
# 23           Mount Washington             4
# 21             East Allegheny             4
# 27                    Bon Air             3
# 24                    Larimer             3
# 37           Allegheny Center             3
# 20                   Sheraden             3
# 12                Polish Hill             3
# 10                 Bloomfield             2
# 11                 Greenfield             2
# 39                Perry South             2
# 38   Lincoln-Lemington-Belmar             2
# 2              Swisshelm Park             2
# 51                    Windgap             2
# 44              Highland Park             2
# 8                   Arlington             2
# 32        Squirrel Hill North             2
# 42             Allegheny West             2
# 28                      Bluff             2
# 46         Marshall-Shadeland             2
# 25               East Liberty             2
# 13        Lower Lawrenceville             2
# 14           Brighton Heights             2
# 49                    Elliott             1
# 45       California-Kirkbride             1
# 43             Homewood South             1
# 47                South Shore             1
# 50              Regent Square             1
# 48                     Esplen             1
# 26                Summer Hill             1
# 40          Northview Heights             1
# 36      Spring Hill-City View             1
# 34                  Allentown             1
# 31               Point Breeze             1
# 1              Strip District             1
# 22                 Manchester             1
# 19            Central Oakland             1
# 17                 Banksville             1
# 16                  Beechview             1
# 6                   Brookline             1
# 52                North Shore             1

# %%
bridgescount.plot.bar()

# %%
best = bridgescount_sorted['neighborhood'].iloc[0]
bestnumber = bridgescount_sorted['# of bridges'].iloc[0]
print("The neighborhood with the most bridges is", best, "with", bestnumber, "bridges and therefore is the best in this category.")
# Out:
# The neighborhood with the most bridges is Squirrel Hill South with 14 bridges and therefore is the best in this category.
